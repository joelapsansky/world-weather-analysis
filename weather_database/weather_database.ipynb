# %%
# Import dependencies
import numpy as np
import time
import pandas as pd

# %%
# Create set of 2K random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lats_lngs = zip(lats, lngs)

# %%
# Add to list
coordinates = list(lats_lngs)

# %%
# Import citipy module
from citipy import citipy

# %%
# Create list
cities = []

# Get nearest city and add to list if unique
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    if city not in cities:
        cities.append(city)
        
# See length of list
len(cities)
# Out:
# 758

# %%
# Import requests library and API key
import requests
from config import weather_api_key

# %%
# Create URL variable for API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_url = url + "&q=" + city.replace(" ","+")
city_weather = requests.get(city_url)
print(city_weather.status_code)
# Out:
# 200

# %%
# Create list to hold weather data from API call
city_data = []

# Loop through all of the cities in the list
print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):

    # Group in sets of 50
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log URL, record, set number, and city
    print(f"Processing record {record_count} of set {set_count} | {city}")
    
    # Increase record count
    record_count += 1
    
    # Wait to avoid hitting query limit
    time.sleep(5)
    
    # Run API request
    try:
        city_weather = requests.get(city_url).json()
        
        # Parese out data in order
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append city info to city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})
    
    # If error, skip
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing record 1 of set 1 | khandbari
# Processing record 2 of set 1 | taolanaro
# City not found. Skipping...
# Processing record 3 of set 1 | marcali
# Processing record 4 of set 1 | atuona
# Processing record 5 of set 1 | williston
# Processing record 6 of set 1 | rikitea
# Processing record 7 of set 1 | mahebourg
# Processing record 8 of set 1 | mar del plata
# Processing record 9 of set 1 | vaini
# Processing record 10 of set 1 | nieuw amsterdam
# Processing record 11 of set 1 | vaitupu
# City not found. Skipping...
# Processing record 12 of set 1 | hermanus
# Processing record 13 of set 1 | sioux lookout
# Processing record 14 of set 1 | new norfolk
# Processing record 15 of set 1 | olafsvik
# Processing record 16 of set 1 | thompson
# Processing record 17 of set 1 | touros
# Processing record 18 of set 1 | georgetown
# Processing record 19 of set 1 | puerto madryn
# Processing record 20 of set 1 | ushuaia
# Processing record 21 of set 1 | salta
# Processing record 22 of set 1 | punta arenas
# Processing record 23 of set 1 | chiang klang
# Processing record 24 of set 1 | faya
# Processing record 25 of set 1 | mataura
# Processing record 26 of set 1 | loandjili
# Processing record 27 of set 1 | cabedelo
# Processing record 28 of set 1 | surt
# Processing record 29 of set 1 | richards bay
# Processing record 30 of set 1 | porosozero
# Processing record 31 of set 1 | busselton
# Processing record 32 of set 1 | isilkul
# Processing record 33 of set 1 | conde
# Processing record 34 of set 1 | saleaula
# City not found. Skipping...
# Processing record 35 of set 1 | zalantun
# Processing record 36 of set 1 | port blair
# Processing record 37 of set 1 | marquette
# Processing record 38 of set 1 | luderitz
# Processing record 39 of set 1 | sentyabrskiy
# City not found. Skipping...
# Processing record 40 of set 1 | lorengau
# Processing record 41 of set 1 | mao
# Processing record 42 of set 1 | bengkulu
# Processing record 43 of set 1 | meyungs
# City not found. Skipping...
# Processing record 44 of set 1 | meadow lake
# Processing record 45 of set 1 | ilulissat
# Processing record 46 of set 1 | hobart
# Processing record 47 of set 1 | karaul
# City not found. Skipping...
# Processing record 48 of set 1 | plyussa
# Processing record 49 of set 1 | husavik
# Processing record 50 of set 1 | nehe
# Processing record 1 of set 2 | koungou
# Processing record 2 of set 2 | rincon
# Processing record 3 of set 2 | vila velha
# Processing record 4 of set 2 | wakkanai
# Processing record 5 of set 2 | jamestown
# Processing record 6 of set 2 | magenta
# Processing record 7 of set 2 | ashtabula
# Processing record 8 of set 2 | port elizabeth
# Processing record 9 of set 2 | lebu
# Processing record 10 of set 2 | albany
# Processing record 11 of set 2 | saint-joseph
# Processing record 12 of set 2 | hilo
# Processing record 13 of set 2 | puerto ayora
# Processing record 14 of set 2 | anadyr
# Processing record 15 of set 2 | avarua
# Processing record 16 of set 2 | suhbaatar
# Processing record 17 of set 2 | buraydah
# Processing record 18 of set 2 | poum
# Processing record 19 of set 2 | esperance
# Processing record 20 of set 2 | tabou
# Processing record 21 of set 2 | bluff
# Processing record 22 of set 2 | rungata
# City not found. Skipping...
# Processing record 23 of set 2 | fortuna
# Processing record 24 of set 2 | tsihombe
# City not found. Skipping...
# Processing record 25 of set 2 | taoudenni
# Processing record 26 of set 2 | kishni
# Processing record 27 of set 2 | hithadhoo
# Processing record 28 of set 2 | astipalaia
# City not found. Skipping...
# Processing record 29 of set 2 | pacific grove
# Processing record 30 of set 2 | barentsburg
# City not found. Skipping...
# Processing record 31 of set 2 | yellowknife
# Processing record 32 of set 2 | saskylakh
# Processing record 33 of set 2 | cape town
# Processing record 34 of set 2 | hobyo
# Processing record 35 of set 2 | bethel
# Processing record 36 of set 2 | poyarkovo
# Processing record 37 of set 2 | clyde river
# Processing record 38 of set 2 | namibe
# Processing record 39 of set 2 | salalah
# Processing record 40 of set 2 | arraial do cabo
# Processing record 41 of set 2 | edd
# Processing record 42 of set 2 | pemberton
# Processing record 43 of set 2 | hofn
# Processing record 44 of set 2 | liberty
# Processing record 45 of set 2 | bukachacha
# Processing record 46 of set 2 | iranshahr
# Processing record 47 of set 2 | san cristobal
# Processing record 48 of set 2 | cockburn harbour
# City not found. Skipping...
# Processing record 49 of set 2 | aklavik
# Processing record 50 of set 2 | namatanai
# Processing record 1 of set 3 | brigantine
# Processing record 2 of set 3 | khatanga
# Processing record 3 of set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing record 4 of set 3 | hommelvik
# Processing record 5 of set 3 | baykit
# Processing record 6 of set 3 | kapaa
# Processing record 7 of set 3 | ipixuna
# Processing record 8 of set 3 | pahalgam
# Processing record 9 of set 3 | port alfred
# Processing record 10 of set 3 | carnarvon
# Processing record 11 of set 3 | aberdeen
# Processing record 12 of set 3 | faanui
# Processing record 13 of set 3 | tiksi
# Processing record 14 of set 3 | sibolga
# Processing record 15 of set 3 | zaraza
# Processing record 16 of set 3 | vila franca do campo
# Processing record 17 of set 3 | port hawkesbury
# Processing record 18 of set 3 | havelock
# Processing record 19 of set 3 | ancud
# Processing record 20 of set 3 | leshukonskoye
# Processing record 21 of set 3 | saint-philippe
# Processing record 22 of set 3 | hami
# Processing record 23 of set 3 | longyearbyen
# Processing record 24 of set 3 | sitka
# Processing record 25 of set 3 | ponta do sol
# Processing record 26 of set 3 | samarai
# Processing record 27 of set 3 | kaitangata
# Processing record 28 of set 3 | marshall
# Processing record 29 of set 3 | airai
# Processing record 30 of set 3 | lompoc
# Processing record 31 of set 3 | pisco
# Processing record 32 of set 3 | tebingtinggi
# Processing record 33 of set 3 | oskarshamn
# Processing record 34 of set 3 | abrau-dyurso
# Processing record 35 of set 3 | lincoln village
# Processing record 36 of set 3 | bargal
# City not found. Skipping...
# Processing record 37 of set 3 | ghanzi
# Processing record 38 of set 3 | umzimvubu
# City not found. Skipping...
# Processing record 39 of set 3 | padang
# Processing record 40 of set 3 | iqaluit
# Processing record 41 of set 3 | tura
# Processing record 42 of set 3 | bhag
# Processing record 43 of set 3 | harnosand
# Processing record 44 of set 3 | asosa
# Processing record 45 of set 3 | nurota
# Processing record 46 of set 3 | saint george
# Processing record 47 of set 3 | castro
# Processing record 48 of set 3 | santa fe
# Processing record 49 of set 3 | banda aceh
# Processing record 50 of set 3 | toora-khem
# Processing record 1 of set 4 | dajal
# Processing record 2 of set 4 | sinjar
# Processing record 3 of set 4 | alzamay
# Processing record 4 of set 4 | san rafael
# Processing record 5 of set 4 | nanortalik
# Processing record 6 of set 4 | caravelas
# Processing record 7 of set 4 | sungaipenuh
# Processing record 8 of set 4 | barrow
# Processing record 9 of set 4 | krasnoselkup
# Processing record 10 of set 4 | teahupoo
# Processing record 11 of set 4 | kaseda
# Processing record 12 of set 4 | saldanha
# Processing record 13 of set 4 | yulara
# Processing record 14 of set 4 | broome
# Processing record 15 of set 4 | araioses
# Processing record 16 of set 4 | ruatoria
# City not found. Skipping...
# Processing record 17 of set 4 | port augusta
# Processing record 18 of set 4 | babahoyo
# Processing record 19 of set 4 | cidreira
# Processing record 20 of set 4 | selizharovo
# Processing record 21 of set 4 | yambio
# Processing record 22 of set 4 | kizema
# Processing record 23 of set 4 | ostrovnoy
# Processing record 24 of set 4 | methoni
# Processing record 25 of set 4 | hovd
# Processing record 26 of set 4 | grand river south east
# City not found. Skipping...
# Processing record 27 of set 4 | mukhen
# Processing record 28 of set 4 | itarema
# Processing record 29 of set 4 | usinsk
# Processing record 30 of set 4 | hasaki
# Processing record 31 of set 4 | nizhneyansk
# City not found. Skipping...
# Processing record 32 of set 4 | pevek
# Processing record 33 of set 4 | sofiyivka
# Processing record 34 of set 4 | port hardy
# Processing record 35 of set 4 | plettenberg bay
# Processing record 36 of set 4 | tamandare
# Processing record 37 of set 4 | korla
# Processing record 38 of set 4 | belushya guba
# City not found. Skipping...
# Processing record 39 of set 4 | igra
# Processing record 40 of set 4 | souillac
# Processing record 41 of set 4 | tuktoyaktuk
# Processing record 42 of set 4 | kahului
# Processing record 43 of set 4 | barguzin
# Processing record 44 of set 4 | ayer itam
# City not found. Skipping...
# Processing record 45 of set 4 | chokurdakh
# Processing record 46 of set 4 | kavieng
# Processing record 47 of set 4 | fairbanks
# Processing record 48 of set 4 | severo-kurilsk
# Processing record 49 of set 4 | mys shmidta
# City not found. Skipping...
# Processing record 50 of set 4 | atambua
# Processing record 1 of set 5 | hit
# Processing record 2 of set 5 | badou
# Processing record 3 of set 5 | dikson
# Processing record 4 of set 5 | codrington
# Processing record 5 of set 5 | lanxi
# Processing record 6 of set 5 | itapolis
# Processing record 7 of set 5 | chute-aux-outardes
# Processing record 8 of set 5 | homer
# Processing record 9 of set 5 | plainview
# Processing record 10 of set 5 | north bend
# Processing record 11 of set 5 | bredasdorp
# Processing record 12 of set 5 | seminole
# Processing record 13 of set 5 | linhai
# Processing record 14 of set 5 | nikolayevka
# Processing record 15 of set 5 | samusu
# City not found. Skipping...
# Processing record 16 of set 5 | butaritari
# Processing record 17 of set 5 | maragogi
# Processing record 18 of set 5 | tuatapere
# Processing record 19 of set 5 | sobolevo
# Processing record 20 of set 5 | bereda
# Processing record 21 of set 5 | myanaung
# Processing record 22 of set 5 | galle
# Processing record 23 of set 5 | tungkang
# City not found. Skipping...
# Processing record 24 of set 5 | nola
# Processing record 25 of set 5 | qaanaaq
# Processing record 26 of set 5 | erenhot
# Processing record 27 of set 5 | odweyne
# Processing record 28 of set 5 | amderma
# City not found. Skipping...
# Processing record 29 of set 5 | aykhal
# Processing record 30 of set 5 | atar
# Processing record 31 of set 5 | sola
# Processing record 32 of set 5 | labuhan
# Processing record 33 of set 5 | chuy
# Processing record 34 of set 5 | vardo
# Processing record 35 of set 5 | laurel
# Processing record 36 of set 5 | yaan
# Processing record 37 of set 5 | mildura
# Processing record 38 of set 5 | dingle
# Processing record 39 of set 5 | chinsali
# Processing record 40 of set 5 | sinegorye
# Processing record 41 of set 5 | sept-iles
# Processing record 42 of set 5 | port macquarie
# Processing record 43 of set 5 | kargat
# Processing record 44 of set 5 | atasu
# Processing record 45 of set 5 | ahipara
# Processing record 46 of set 5 | keti bandar
# Processing record 47 of set 5 | bathsheba
# Processing record 48 of set 5 | tasiilaq
# Processing record 49 of set 5 | sogdiondon
# City not found. Skipping...
# Processing record 50 of set 5 | jalu
# Processing record 1 of set 6 | seoul
# Processing record 2 of set 6 | portmore
# Processing record 3 of set 6 | ijaki
# City not found. Skipping...
# Processing record 4 of set 6 | tautira
# Processing record 5 of set 6 | murdochville
# Processing record 6 of set 6 | bima
# Processing record 7 of set 6 | baherden
# Processing record 8 of set 6 | plouzane
# Processing record 9 of set 6 | flinders
# Processing record 10 of set 6 | juneau
# Processing record 11 of set 6 | klaksvik
# Processing record 12 of set 6 | sao jose da coroa grande
# Processing record 13 of set 6 | tosham
# Processing record 14 of set 6 | pontes e lacerda
# Processing record 15 of set 6 | ostuacan
# Processing record 16 of set 6 | alice springs
# Processing record 17 of set 6 | labuan
# Processing record 18 of set 6 | camacha
# Processing record 19 of set 6 | gat
# Processing record 20 of set 6 | ust-ilimsk
# Processing record 21 of set 6 | dudinka
# Processing record 22 of set 6 | santa isabel do rio negro
# Processing record 23 of set 6 | nikolskoye
# Processing record 24 of set 6 | te anau
# Processing record 25 of set 6 | cordele
# Processing record 26 of set 6 | chagda
# City not found. Skipping...
# Processing record 27 of set 6 | lagoa
# Processing record 28 of set 6 | muisne
# Processing record 29 of set 6 | guerrero negro
# Processing record 30 of set 6 | rawson
# Processing record 31 of set 6 | saint-pierre
# Processing record 32 of set 6 | kilindoni
# Processing record 33 of set 6 | chumikan
# Processing record 34 of set 6 | bur gabo
# City not found. Skipping...
# Processing record 35 of set 6 | bara
# Processing record 36 of set 6 | tombouctou
# Processing record 37 of set 6 | darhan
# Processing record 38 of set 6 | caconda
# Processing record 39 of set 6 | torbay
# Processing record 40 of set 6 | machali
# Processing record 41 of set 6 | one hundred mile house
# City not found. Skipping...
# Processing record 42 of set 6 | belaya gora
# Processing record 43 of set 6 | falealupo
# City not found. Skipping...
# Processing record 44 of set 6 | portland
# Processing record 45 of set 6 | acari
# Processing record 46 of set 6 | xambioa
# Processing record 47 of set 6 | belmonte
# Processing record 48 of set 6 | dhidhdhoo
# Processing record 49 of set 6 | norman wells
# Processing record 50 of set 6 | xining
# Processing record 1 of set 7 | verkhoyansk
# Processing record 2 of set 7 | kukmor
# Processing record 3 of set 7 | ambunti
# Processing record 4 of set 7 | ewa beach
# Processing record 5 of set 7 | sarai
# Processing record 6 of set 7 | jizan
# Processing record 7 of set 7 | hoi an
# Processing record 8 of set 7 | eureka
# Processing record 9 of set 7 | sao filipe
# Processing record 10 of set 7 | severobaykalsk
# Processing record 11 of set 7 | biloela
# Processing record 12 of set 7 | sao joao da barra
# Processing record 13 of set 7 | panzhihua
# Processing record 14 of set 7 | young
# Processing record 15 of set 7 | cherskiy
# Processing record 16 of set 7 | zhanaozen
# Processing record 17 of set 7 | jesup
# Processing record 18 of set 7 | mount isa
# Processing record 19 of set 7 | kankon
# Processing record 20 of set 7 | skagastrond
# City not found. Skipping...
# Processing record 21 of set 7 | vilhena
# Processing record 22 of set 7 | sistranda
# Processing record 23 of set 7 | riosucio
# Processing record 24 of set 7 | cayenne
# Processing record 25 of set 7 | tabiauea
# City not found. Skipping...
# Processing record 26 of set 7 | paamiut
# Processing record 27 of set 7 | gornopravdinsk
# Processing record 28 of set 7 | yamada
# Processing record 29 of set 7 | sicuani
# Processing record 30 of set 7 | madona
# Processing record 31 of set 7 | hjallerup
# Processing record 32 of set 7 | fare
# Processing record 33 of set 7 | labrea
# Processing record 34 of set 7 | gushikawa
# Processing record 35 of set 7 | oistins
# Processing record 36 of set 7 | tiznit
# Processing record 37 of set 7 | tubuala
# Processing record 38 of set 7 | muswellbrook
# Processing record 39 of set 7 | comodoro rivadavia
# Processing record 40 of set 7 | marystown
# Processing record 41 of set 7 | oudtshoorn
# Processing record 42 of set 7 | vrbno pod pradedem
# Processing record 43 of set 7 | bakchar
# Processing record 44 of set 7 | ribeira grande
# Processing record 45 of set 7 | sinnamary
# Processing record 46 of set 7 | vao
# Processing record 47 of set 7 | naze
# Processing record 48 of set 7 | laguna
# Processing record 49 of set 7 | provideniya
# Processing record 50 of set 7 | catuday
# Processing record 1 of set 8 | bonthe
# Processing record 2 of set 8 | mehamn
# Processing record 3 of set 8 | oktyabrskoye
# Processing record 4 of set 8 | hambantota
# Processing record 5 of set 8 | mount gambier
# Processing record 6 of set 8 | goderich
# Processing record 7 of set 8 | ailigandi
# Processing record 8 of set 8 | simoes
# Processing record 9 of set 8 | vostok
# Processing record 10 of set 8 | kamaishi
# Processing record 11 of set 8 | bahia blanca
# Processing record 12 of set 8 | ixtapa
# Processing record 13 of set 8 | gubkinskiy
# Processing record 14 of set 8 | orikum
# Processing record 15 of set 8 | bambous virieux
# Processing record 16 of set 8 | dawlatabad
# Processing record 17 of set 8 | victoria
# Processing record 18 of set 8 | kruisfontein
# Processing record 19 of set 8 | aksarka
# Processing record 20 of set 8 | lavrentiya
# Processing record 21 of set 8 | meulaboh
# Processing record 22 of set 8 | margate
# Processing record 23 of set 8 | castelnau-le-lez
# Processing record 24 of set 8 | severodvinsk
# Processing record 25 of set 8 | canavieiras
# Processing record 26 of set 8 | trabzon
# Processing record 27 of set 8 | levski
# Processing record 28 of set 8 | geraldton
# Processing record 29 of set 8 | amga
# Processing record 30 of set 8 | avera
# Processing record 31 of set 8 | acarau
# Processing record 32 of set 8 | deputatskiy
# Processing record 33 of set 8 | shimoda
# Processing record 34 of set 8 | faranah
# Processing record 35 of set 8 | nantucket
# Processing record 36 of set 8 | bagdarin
# Processing record 37 of set 8 | santiago
# Processing record 38 of set 8 | jiddah
# City not found. Skipping...
# Processing record 39 of set 8 | balsas
# Processing record 40 of set 8 | krutikha
# Processing record 41 of set 8 | askarovo
# Processing record 42 of set 8 | maunabo
# Processing record 43 of set 8 | chapais
# Processing record 44 of set 8 | takoradi
# Processing record 45 of set 8 | moranbah
# Processing record 46 of set 8 | cabo san lucas
# Processing record 47 of set 8 | nosy varika
# Processing record 48 of set 8 | shubarshi
# Processing record 49 of set 8 | la palma
# Processing record 50 of set 8 | gizo
# Processing record 1 of set 9 | farsund
# Processing record 2 of set 9 | charlestown
# Processing record 3 of set 9 | mineros
# Processing record 4 of set 9 | san andres
# Processing record 5 of set 9 | tashtagol
# Processing record 6 of set 9 | victoriaville
# Processing record 7 of set 9 | east london
# Processing record 8 of set 9 | zhanatas
# City not found. Skipping...
# Processing record 9 of set 9 | constitucion
# Processing record 10 of set 9 | san patricio
# Processing record 11 of set 9 | sakaiminato
# Processing record 12 of set 9 | kuche
# City not found. Skipping...
# Processing record 13 of set 9 | kodinsk
# Processing record 14 of set 9 | puerto narino
# Processing record 15 of set 9 | gaoyou
# Processing record 16 of set 9 | ramasukha
# City not found. Skipping...
# Processing record 17 of set 9 | srednekolymsk
# Processing record 18 of set 9 | pokhara
# Processing record 19 of set 9 | saint-augustin
# Processing record 20 of set 9 | merauke
# Processing record 21 of set 9 | jackson
# Processing record 22 of set 9 | toliary
# City not found. Skipping...
# Processing record 23 of set 9 | nhulunbuy
# Processing record 24 of set 9 | zeya
# Processing record 25 of set 9 | buenaventura
# Processing record 26 of set 9 | abdulino
# Processing record 27 of set 9 | koumac
# Processing record 28 of set 9 | khani
# Processing record 29 of set 9 | morehead
# Processing record 30 of set 9 | morris
# Processing record 31 of set 9 | kodiak
# Processing record 32 of set 9 | vinh
# Processing record 33 of set 9 | grindavik
# Processing record 34 of set 9 | shelburne
# Processing record 35 of set 9 | batagay
# Processing record 36 of set 9 | verkh-usugli
# Processing record 37 of set 9 | mwinilunga
# Processing record 38 of set 9 | havoysund
# Processing record 39 of set 9 | upernavik
# Processing record 40 of set 9 | shenjiamen
# Processing record 41 of set 9 | diamantino
# Processing record 42 of set 9 | birjand
# Processing record 43 of set 9 | kulhudhuffushi
# Processing record 44 of set 9 | ialibu
# Processing record 45 of set 9 | kutum
# Processing record 46 of set 9 | leningradskiy
# Processing record 47 of set 9 | coquimbo
# Processing record 48 of set 9 | miri
# Processing record 49 of set 9 | privolzhskiy
# Processing record 50 of set 9 | high rock
# Processing record 1 of set 10 | dujuma
# City not found. Skipping...
# Processing record 2 of set 10 | bolungarvik
# City not found. Skipping...
# Processing record 3 of set 10 | asau
# Processing record 4 of set 10 | huangmei
# Processing record 5 of set 10 | chicama
# Processing record 6 of set 10 | katsuura
# Processing record 7 of set 10 | brae
# Processing record 8 of set 10 | liyang
# Processing record 9 of set 10 | port-cartier
# Processing record 10 of set 10 | palmas
# Processing record 11 of set 10 | fuling
# Processing record 12 of set 10 | pitimbu
# Processing record 13 of set 10 | estelle
# Processing record 14 of set 10 | healesville
# Processing record 15 of set 10 | baghdad
# Processing record 16 of set 10 | sisimiut
# Processing record 17 of set 10 | manuk mangkaw
# Processing record 18 of set 10 | yarmouth
# Processing record 19 of set 10 | baruun-urt
# Processing record 20 of set 10 | gunnedah
# Processing record 21 of set 10 | chernyshevskiy
# Processing record 22 of set 10 | nelson bay
# Processing record 23 of set 10 | beroroha
# Processing record 24 of set 10 | qabis
# City not found. Skipping...
# Processing record 25 of set 10 | thongwa
# Processing record 26 of set 10 | zambezi
# Processing record 27 of set 10 | mandalgovi
# Processing record 28 of set 10 | mayo
# Processing record 29 of set 10 | bay roberts
# Processing record 30 of set 10 | tambo
# Processing record 31 of set 10 | liapades
# City not found. Skipping...
# Processing record 32 of set 10 | kota belud
# Processing record 33 of set 10 | half moon bay
# Processing record 34 of set 10 | olinda
# Processing record 35 of set 10 | penha
# Processing record 36 of set 10 | weiser
# Processing record 37 of set 10 | attawapiskat
# City not found. Skipping...
# Processing record 38 of set 10 | havre-saint-pierre
# Processing record 39 of set 10 | burla
# Processing record 40 of set 10 | tarboro
# Processing record 41 of set 10 | gravdal
# Processing record 42 of set 10 | portel
# Processing record 43 of set 10 | willowmore
# Processing record 44 of set 10 | key largo
# Processing record 45 of set 10 | garhi khairo
# Processing record 46 of set 10 | grajau
# Processing record 47 of set 10 | port-gentil
# Processing record 48 of set 10 | hun
# Processing record 49 of set 10 | tadine
# Processing record 50 of set 10 | berlevag
# Processing record 1 of set 11 | karratha
# Processing record 2 of set 11 | ballina
# Processing record 3 of set 11 | kloulklubed
# Processing record 4 of set 11 | huarmey
# Processing record 5 of set 11 | korcula
# Processing record 6 of set 11 | wairoa
# Processing record 7 of set 11 | verkhnevilyuysk
# Processing record 8 of set 11 | luena
# Processing record 9 of set 11 | jian
# Processing record 10 of set 11 | rizhao
# Processing record 11 of set 11 | cape canaveral
# Processing record 12 of set 11 | alyangula
# Processing record 13 of set 11 | tocopilla
# Processing record 14 of set 11 | aleksandrov gay
# Processing record 15 of set 11 | kabompo
# Processing record 16 of set 11 | pictou
# Processing record 17 of set 11 | wahran
# City not found. Skipping...
# Processing record 18 of set 11 | makakilo city
# Processing record 19 of set 11 | inveraray
# City not found. Skipping...
# Processing record 20 of set 11 | ambilobe
# Processing record 21 of set 11 | kusk
# City not found. Skipping...
# Processing record 22 of set 11 | konstantinovka
# Processing record 23 of set 11 | ola
# Processing record 24 of set 11 | yar-sale
# Processing record 25 of set 11 | yeniseysk
# Processing record 26 of set 11 | zyryanka
# Processing record 27 of set 11 | lere
# Processing record 28 of set 11 | marcona
# City not found. Skipping...
# Processing record 29 of set 11 | jamame
# Processing record 30 of set 11 | muzhi
# Processing record 31 of set 11 | wawa
# Processing record 32 of set 11 | soyo
# Processing record 33 of set 11 | marsh harbour
# Processing record 34 of set 11 | bontang
# Processing record 35 of set 11 | hamburg
# Processing record 36 of set 11 | neubrandenburg
# Processing record 37 of set 11 | marsabit
# Processing record 38 of set 11 | minot
# Processing record 39 of set 11 | muros
# Processing record 40 of set 11 | sodertalje
# City not found. Skipping...
# Processing record 41 of set 11 | morondava
# Processing record 42 of set 11 | mozarlandia
# Processing record 43 of set 11 | mogochin
# City not found. Skipping...
# Processing record 44 of set 11 | rovaniemi
# Processing record 45 of set 11 | ust-nera
# Processing record 46 of set 11 | popondetta
# Processing record 47 of set 11 | tumannyy
# City not found. Skipping...
# Processing record 48 of set 11 | svencionys
# Processing record 49 of set 11 | lolua
# City not found. Skipping...
# Processing record 50 of set 11 | wellington
# Processing record 1 of set 12 | ulladulla
# Processing record 2 of set 12 | hohhot
# Processing record 3 of set 12 | ilo
# Processing record 4 of set 12 | olenino
# Processing record 5 of set 12 | katsiveli
# City not found. Skipping...
# Processing record 6 of set 12 | shilovo
# Processing record 7 of set 12 | grand centre
# City not found. Skipping...
# Processing record 8 of set 12 | jumla
# Processing record 9 of set 12 | qostanay
# Processing record 10 of set 12 | galgani
# City not found. Skipping...
# Processing record 11 of set 12 | flin flon
# Processing record 12 of set 12 | ardistan
# City not found. Skipping...
# Processing record 13 of set 12 | necochea
# Processing record 14 of set 12 | antofagasta
# Processing record 15 of set 12 | lazaro cardenas
# Processing record 16 of set 12 | male
# Processing record 17 of set 12 | palana
# Processing record 18 of set 12 | kungurtug
# Processing record 19 of set 12 | mpulungu
# Processing record 20 of set 12 | isla vista
# Processing record 21 of set 12 | minas
# Processing record 22 of set 12 | iquitos
# Processing record 23 of set 12 | tarko-sale
# Processing record 24 of set 12 | cuxhaven
# Processing record 25 of set 12 | williams lake
# Processing record 26 of set 12 | nizhniy baskunchak
# Processing record 27 of set 12 | bonavista
# Processing record 28 of set 12 | beringovskiy
# Processing record 29 of set 12 | rocha
# Processing record 30 of set 12 | abha
# Processing record 31 of set 12 | bahia honda
# Processing record 32 of set 12 | murindo
# Processing record 33 of set 12 | praia da vitoria
# Processing record 34 of set 12 | bartica
# Processing record 35 of set 12 | rantepao
# Processing record 36 of set 12 | keetmanshoop
# Processing record 37 of set 12 | ambon
# Processing record 38 of set 12 | biltine
# Processing record 39 of set 12 | bulolo
# Processing record 40 of set 12 | taltal
# Processing record 41 of set 12 | warri
# Processing record 42 of set 12 | guiratinga
# Processing record 43 of set 12 | walvis bay
# Processing record 44 of set 12 | ravar
# Processing record 45 of set 12 | mouila
# Processing record 46 of set 12 | merrill
# Processing record 47 of set 12 | hervey bay
# Processing record 48 of set 12 | takaka
# Processing record 49 of set 12 | samalaeulu
# City not found. Skipping...
# Processing record 50 of set 12 | panjab
# Processing record 1 of set 13 | la ronge
# Processing record 2 of set 13 | port pirie
# Processing record 3 of set 13 | yangambi
# Processing record 4 of set 13 | newport
# Processing record 5 of set 13 | balkhash
# Processing record 6 of set 13 | diapaga
# Processing record 7 of set 13 | formosa
# Processing record 8 of set 13 | san policarpo
# Processing record 9 of set 13 | gilbues
# Processing record 10 of set 13 | arauco
# Processing record 11 of set 13 | vryburg
# Processing record 12 of set 13 | strathmore
# Processing record 13 of set 13 | sedelnikovo
# City not found. Skipping...
# Processing record 14 of set 13 | magadan
# Processing record 15 of set 13 | fort nelson
# Processing record 16 of set 13 | tahta
# Processing record 17 of set 13 | santa cruz
# Processing record 18 of set 13 | corrente
# Processing record 19 of set 13 | oum hadjer
# Processing record 20 of set 13 | sao joao do paraiso
# Processing record 21 of set 13 | suntar
# Processing record 22 of set 13 | tarudant
# City not found. Skipping...
# Processing record 23 of set 13 | cervo
# Processing record 24 of set 13 | malwan
# City not found. Skipping...
# Processing record 25 of set 13 | san jose
# Processing record 26 of set 13 | pangnirtung
# Processing record 27 of set 13 | segou
# Processing record 28 of set 13 | kununurra
# Processing record 29 of set 13 | isangel
# Processing record 30 of set 13 | inderborskiy
# City not found. Skipping...
# Processing record 31 of set 13 | sikasso
# Processing record 32 of set 13 | armacao dos buzios
# City not found. Skipping...
# Processing record 33 of set 13 | warqla
# City not found. Skipping...
# Processing record 34 of set 13 | hay river
# Processing record 35 of set 13 | luba
# Processing record 36 of set 13 | caibarien
# Processing record 37 of set 13 | aleysk
# Processing record 38 of set 13 | emerald
# Processing record 39 of set 13 | yanam
# Processing record 40 of set 13 | santa rosa
# Processing record 41 of set 13 | udachnyy
# Processing record 42 of set 13 | corbu
# Processing record 43 of set 13 | esso
# Processing record 44 of set 13 | coihaique
# Processing record 45 of set 13 | nome
# Processing record 46 of set 13 | pampas
# Processing record 47 of set 13 | quatre cocos
# Processing record 48 of set 13 | aasiaat
# Processing record 49 of set 13 | kazalinsk
# City not found. Skipping...
# Processing record 50 of set 13 | borger
# Processing record 1 of set 14 | yurginskoye
# Processing record 2 of set 14 | nuuk
# Processing record 3 of set 14 | urumqi
# Processing record 4 of set 14 | chunskiy
# Processing record 5 of set 14 | la asuncion
# Processing record 6 of set 14 | abu dhabi
# Processing record 7 of set 14 | buala
# Processing record 8 of set 14 | nyurba
# Processing record 9 of set 14 | cururupu
# Processing record 10 of set 14 | la cumbre
# Processing record 11 of set 14 | eyl
# Processing record 12 of set 14 | miramar
# Processing record 13 of set 14 | karasjok
# Processing record 14 of set 14 | araouane
# Processing record 15 of set 14 | semey
# Processing record 16 of set 14 | halalo
# City not found. Skipping...
# Processing record 17 of set 14 | lucelia
# Processing record 18 of set 14 | anshun
# Processing record 19 of set 14 | henties bay
# Processing record 20 of set 14 | shirokiy
# Processing record 21 of set 14 | buturlinovka
# Processing record 22 of set 14 | komsomolskiy
# Processing record 23 of set 14 | korem
# Processing record 24 of set 14 | yatou
# Processing record 25 of set 14 | talara
# Processing record 26 of set 14 | mashhad
# Processing record 27 of set 14 | raahe
# Processing record 28 of set 14 | sampit
# Processing record 29 of set 14 | tremedal
# Processing record 30 of set 14 | auki
# Processing record 31 of set 14 | ngunguru
# Processing record 32 of set 14 | tolaga bay
# Processing record 33 of set 14 | soverato
# Processing record 34 of set 14 | mercedes
# Processing record 35 of set 14 | aku
# Processing record 36 of set 14 | khobi
# Processing record 37 of set 14 | qandala
# Processing record 38 of set 14 | tuburan
# Processing record 39 of set 14 | gimbi
# Processing record 40 of set 14 | sterling
# Processing record 41 of set 14 | komsomolets
# Processing record 42 of set 14 | taylor
# Processing record 43 of set 14 | nayoro
# Processing record 44 of set 14 | kavaratti
# Processing record 45 of set 14 | kizlyar
# Processing record 46 of set 14 | kiruna
# Processing record 47 of set 14 | volzhsk
# Processing record 48 of set 14 | vanersborg
# Processing record 49 of set 14 | multan
# Processing record 50 of set 14 | zasechnoye
# Processing record 1 of set 15 | roslavl
# Processing record 2 of set 15 | paso de carrasco
# Processing record 3 of set 15 | totness
# Processing record 4 of set 15 | aconibe
# Processing record 5 of set 15 | ponta delgada
# Processing record 6 of set 15 | sakakah
# Processing record 7 of set 15 | blackwater
# Processing record 8 of set 15 | awbari
# Processing record 9 of set 15 | rognan
# Processing record 10 of set 15 | denpasar
# Processing record 11 of set 15 | basco
# Processing record 12 of set 15 | burns lake
# Processing record 13 of set 15 | nata
# Processing record 14 of set 15 | mulchen
# Processing record 15 of set 15 | russell
# Processing record 16 of set 15 | rio grande
# Processing record 17 of set 15 | itainopolis
# Processing record 18 of set 15 | ossora
# Processing record 19 of set 15 | celestun
# Processing record 20 of set 15 | vrangel
# Processing record 21 of set 15 | doctor pedro p. pena
# City not found. Skipping...
# Processing record 22 of set 15 | dukat
# Processing record 23 of set 15 | maloshuyka
# City not found. Skipping...
# Processing record 24 of set 15 | kitgum
# Processing record 25 of set 15 | sechura
# Processing record 26 of set 15 | isla mujeres
# Processing record 27 of set 15 | chilca
# Processing record 28 of set 15 | egvekinot
# Processing record 29 of set 15 | bella union
# Processing record 30 of set 15 | ziro
# Processing record 31 of set 15 | kolokani
# Processing record 32 of set 15 | gondar
# Processing record 33 of set 15 | college
# Processing record 34 of set 15 | sao jose de ribamar
# Processing record 35 of set 15 | lashio
# Processing record 36 of set 15 | qinzhou
# Processing record 37 of set 15 | honggang
# Processing record 38 of set 15 | prado
# Processing record 39 of set 15 | san carlos de bariloche
# Processing record 40 of set 15 | brasilia
# Processing record 41 of set 15 | sainte-anne-des-monts
# Processing record 42 of set 15 | alakurtti
# Processing record 43 of set 15 | narsaq
# Processing record 44 of set 15 | taburi
# City not found. Skipping...
# Processing record 45 of set 15 | sorland
# Processing record 46 of set 15 | kailua
# Processing record 47 of set 15 | darlowo
# Processing record 48 of set 15 | llanes
# Processing record 49 of set 15 | ganzhou
# Processing record 50 of set 15 | sabha
# Processing record 1 of set 16 | filingue
# Processing record 2 of set 16 | bocas del toro
# Processing record 3 of set 16 | zanjan
# Processing record 4 of set 16 | mareeba
# Processing record 5 of set 16 | bardiyah
# Processing record 6 of set 16 | axim
# Processing record 7 of set 16 | alad
# Processing record 8 of set 16 | plovdiv
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert array of dictionaries to pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Khandbari      NP  27.3747   87.2039     55.29        59          54
# 1          Marcali      HU  46.5850   17.4120     46.40        71           0
# 2           Atuona      PF  -9.8000 -139.0333     78.22        77          59
# 3        Williston      US  48.1470 -103.6180     30.99        60           0
# 4          Rikitea      PF -23.1203 -134.9692     78.62        75           0
# 5        Mahebourg      MU -20.4081   57.7000     80.60        83          75
# 6    Mar Del Plata      AR -38.0023  -57.5575     71.01        83           0
# 7            Vaini      TO -21.2000 -175.2000     80.60        94          90
# 8  Nieuw Amsterdam      SR   5.8833  -55.0833     75.99        89          31
# 9         Hermanus      ZA -34.4187   19.2345     64.99        83          61
#
#    Wind Speed Current Description
# 0        0.69       broken clouds
# 1       19.57           clear sky
# 2       15.43       broken clouds
# 3        5.01           clear sky
# 4       16.02           clear sky
# 5        6.91       broken clouds
# 6        6.91           clear sky
# 7       13.80       moderate rain
# 8        7.34    scattered clouds
# 9        4.00       broken clouds

# %%
# Create the CSV
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
